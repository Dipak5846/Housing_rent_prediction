# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings                                             # only to ignore python warnings
# %matplotlib inline
warnings.simplefilter("ignore")

# %%
data = pd.read_csv('Mumbai_99acers.csv')
data.head(3)
# Out:
#    sl no.                society                   type  \
# 0       1    Bandstand Apartment  Residential Apartment
# 1       2    Fantastic Apartment  Residential Apartment
# 2       3  Gajra Bhoomi Symphony  Residential Apartment
#
#                   location  lattitude  longitude bedrooms  built-up area  \
# 0            Bandra (West)  19.047353  72.820068    2 BHK          800.0
# 1                Khar West  19.071690  72.834127    2 BHK         1050.0
# 2  Sector-20 Koparkhairane  19.109368  73.001346    2 BHK         1050.0
#
#     furnishing                age  ...              dealer       posted  \
# 0    Furnished  5 to 10 years old  ...             PROPBAY  Jul-05-2018
# 1    Furnished   1 to 5 years old  ...             PROPBAY  Jul-05-2018
# 2  Unfurnished   1 to 5 years old  ...  AAKASH REAL ESTATE  Jul-07-2018
#
#   monthly rent property photo  property video  society photo  society video  \
# 0        85000              2               0              3              0
# 1       110000              0               0              0              0
# 2        32000              0               0              0              1
#
#    locality photo  locality video  \
# 0               0               0
# 1               1               0
# 2               0               0
#
#                                          description
# 0  Description : 2 bhk apartment for rent in band...
# 1  Description : 2 bhk apartment for rent in khar...
# 2  Description : 2 bhk flat available for rent in...
#
# [3 rows x 22 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13541 entries, 0 to 13540
# Data columns (total 22 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl no.          13541 non-null  int64
#  1   society         13541 non-null  object
#  2   type            13541 non-null  object
#  3   location        13541 non-null  object
#  4   lattitude       2174 non-null   float64
#  5   longitude       2174 non-null   float64
#  6   bedrooms        13541 non-null  object
#  7   built-up area   13541 non-null  float64
#  8   furnishing      13541 non-null  object
#  9   age             13541 non-null  object
#  10  floor           13541 non-null  object
#  11  total floors    13541 non-null  object
#  12  dealer          13478 non-null  object
#  13  posted          13541 non-null  object
#  14  monthly rent    13541 non-null  int64
#  15  property photo  13541 non-null  int64
#  16  property video  13541 non-null  int64
#  17  society photo   13541 non-null  int64
#  18  society video   13541 non-null  int64
#  19  locality photo  13541 non-null  int64
#  20  locality video  13541 non-null  int64
#  21  description     13541 non-null  object
# dtypes: float64(3), int64(8), object(11)
# memory usage: 2.3+ MB

# %%
df = data.copy()

# %%
df = df.drop(df.iloc[:,[0,4,5,12,13,15,16,17,18,19,20,21]],axis = 1)
df.head()
# Out:
#                  society                   type                 location  \
# 0    Bandstand Apartment  Residential Apartment            Bandra (West)
# 1    Fantastic Apartment  Residential Apartment                Khar West
# 2  Gajra Bhoomi Symphony  Residential Apartment  Sector-20 Koparkhairane
# 3           Crescent Bay  Residential Apartment                    Parel
# 4            Ashwini CHS  Residential Apartment              Tilak Nagar
#
#   bedrooms  built-up area     furnishing                age floor  \
# 0    2 BHK          800.0      Furnished  5 to 10 years old   2nd
# 1    2 BHK         1050.0      Furnished   1 to 5 years old   8th
# 2    2 BHK         1050.0    Unfurnished   1 to 5 years old  14th
# 3    3 BHK         2275.0  Semifurnished   1 to 5 years old  40th
# 4    1 BHK          550.0  Semifurnished  5 to 10 years old   4th
#
#   total floors  monthly rent
# 0            6         85000
# 1           12        110000
# 2           17         32000
# 3           41        150000
# 4            7         27000

# %%
df.isnull().sum()
# Out:
# society          0
# type             0
# location         0
# bedrooms         0
# built-up area    0
# furnishing       0
# age              0
# floor            0
# total floors     0
# monthly rent     0
# dtype: int64

# %%
df.dtypes
# Out:
# society           object
# type              object
# location          object
# bedrooms          object
# built-up area    float64
# furnishing        object
# age               object
# floor             object
# total floors      object
# monthly rent       int64
# dtype: object

# %%
for i in df.columns.drop(['built-up area','monthly rent']):
    df[i] = df[i].apply(lambda x: x.strip())

# %%
df.head()
# Out:
#                  society                   type                 location  \
# 0    Bandstand Apartment  Residential Apartment            Bandra (West)
# 1    Fantastic Apartment  Residential Apartment                Khar West
# 2  Gajra Bhoomi Symphony  Residential Apartment  Sector-20 Koparkhairane
# 3           Crescent Bay  Residential Apartment                    Parel
# 4            Ashwini CHS  Residential Apartment              Tilak Nagar
#
#   bedrooms  built-up area     furnishing                age floor  \
# 0    2 BHK          800.0      Furnished  5 to 10 years old   2nd
# 1    2 BHK         1050.0      Furnished   1 to 5 years old   8th
# 2    2 BHK         1050.0    Unfurnished   1 to 5 years old  14th
# 3    3 BHK         2275.0  Semifurnished   1 to 5 years old  40th
# 4    1 BHK          550.0  Semifurnished  5 to 10 years old   4th
#
#   total floors  monthly rent
# 0            6         85000
# 1           12        110000
# 2           17         32000
# 3           41        150000
# 4            7         27000

# %%
society_count = pd.DataFrame(df['society'].value_counts())
society_count
# Out:
#                                    society
# On Request                            1219
# Lodha New Cuffe Parade                 279
# Lodha Lakeshore Greens                 186
# Crescent Bay                           162
# Ajmera Bhakti Park Sector 1 and 2      160
# ...                                    ...
# Haware Tilak Nagar                       1
# Shree Laxmi Park 1                       1
# Gulmohar House                           1
# Worli Sea Face                           1
# Palm Villa B                             1
#
# [3473 rows x 1 columns]

# %%
society_count[society_count['society']<10].shape
# Out:
# (3292, 1)

# %%
society_count_less_than_10_index_list = society_count[society_count['society']<10].index
df['society'] = df['society'].apply(lambda x: 'other society' if x in society_count_less_than_10_index_list else x)

# %%
df['society'].value_counts()
# Out:
# other society                                5554
# On Request                                   1219
# Lodha New Cuffe Parade                        279
# Lodha Lakeshore Greens                        186
# Crescent Bay                                  162
#                                              ...
# Kesar Harmony                                  10
# Safal Saraswati CHS                            10
# Harmony Co Operative Housing Society           10
# Oberoi Parkview                                10
# Hiranandani Estate, Patlipada, Thane West      10
# Name: society, Length: 182, dtype: int64

# %%
sc = pd.DataFrame(df['society'].value_counts().iloc[1:,])

plt.figure(figsize=(8,28))
sns.barplot(x = 'society', y = sc.index, data=sc)
plt.show()

# %%
df['type'].value_counts()
# Out:
# Residential Apartment      13416
# Studio Apartment              69
# Independent House/Villa       56
# Name: type, dtype: int64

# %%
location_count = pd.DataFrame(df['location'].value_counts())
location_count
# Out:
#                                     location
# Bandra (West)                            571
# Wadala                                   497
# Hiranandani Gardens - Powai              463
# Wadala East                              458
# Chembur (East)                           449
# ...                                      ...
# Sonar Pada                                 1
# Old Mhb, Gorai Road, Borivali West         1
# Parsee Colony                              1
# Lourdes Colony                             1
# Chamundeshwari Nagar                       1
#
# [532 rows x 1 columns]

# %%
location_count_less_than_10_index = location_count[location_count['location']<10].index
df['location'] = df['location'].apply(lambda x: 'other location' if x in location_count_less_than_10_index else x)

# %%
df['location'].value_counts()
# Out:
# other location                 1003
# Bandra (West)                   571
# Wadala                          497
# Hiranandani Gardens - Powai     463
# Wadala East                     458
#                                ...
# Hmpl Surya Nagar                 11
# 4 Bunglows                       10
# Dindoshi                         10
# Sindhi Society Chembur           10
# Sector-6 Nerul                   10
# Name: location, Length: 166, dtype: int64

# %%
location_count = pd.DataFrame(df['location'].value_counts().iloc[1:,])

plt.figure(figsize=(8,28))
sns.barplot(x = 'location', y = location_count.index, data=location_count)
plt.show()

# %%
df.furnishing.value_counts()
# Out:
# Semifurnished    5661
# Unfurnished      4272
# Furnished        3395
# Not Mentioned     213
# Name: furnishing, dtype: int64

# %%
plt.pie(df.furnishing.value_counts(), labels = df.furnishing.value_counts().index)
plt.show()

# %%
df.age.value_counts()
# Out:
# 1 to 5 years old     4783
# 5 to 10 years old    4002
# 0 to 1 years old     2680
# 10+ years old        2030
# Not Mentioned          46
# Name: age, dtype: int64

# %%
df['bedrooms'].value_counts()
# Out:
# 2 BHK        6392
# 3 BHK        3447
# 1 BHK        2906
# 4 BHK         620
# 1 RK           69
# 5 BHK          46
# 4 Bedroom      22
# 1 Bedroom      12
# 2 Bedroom       8
# 3 Bedroom       7
# 6 BHK           5
# 5 Bedroom       4
# 7 Bedroom       2
# 9 Bedroom       1
# Name: bedrooms, dtype: int64

# %%
df['bedrooms'] = df['bedrooms'].apply(lambda x: x.strip(' ')[0])
df['bedrooms'].value_counts()
# Out:
# 2    6400
# 3    3454
# 1    2987
# 4     642
# 5      50
# 6       5
# 7       2
# 9       1
# Name: bedrooms, dtype: int64

# %%
df[df['type'] == 'Independent House/Villa']
# Out:
#               society                     type                     location  \
# 1360       Union Park  Independent House/Villa                      Chembur
# 1606    other society  Independent House/Villa                  Lokhandwala
# 1646    other society  Independent House/Villa               other location
# 1788    Description :  Independent House/Villa                         Juhu
# 1901       On Request  Independent House/Villa             Sector-8 Charkop
# 2122       On Request  Independent House/Villa                         Juhu
# 2124    other society  Independent House/Villa               other location
# 2175    other society  Independent House/Villa               other location
# 2340    other society  Independent House/Villa                      Chembur
# 2377    Description :  Independent House/Villa                     Kharghar
# 2391       On Request  Independent House/Villa               other location
# 5638       On Request  Independent House/Villa                     Kharghar
# 5726    other society  Independent House/Villa                      Chembur
# 5865    other society  Independent House/Villa               Chembur (East)
# 5915    other society  Independent House/Villa                      Manpada
# 6106    other society  Independent House/Villa               Chembur (East)
# 6659    Description :  Independent House/Villa               other location
# 6934   Sindhi Society  Independent House/Villa               Chembur (East)
# 6979    Description :  Independent House/Villa               other location
# 6987       On Request  Independent House/Villa                         Juhu
# 7101    Description :  Independent House/Villa                      Chembur
# 7574    other society  Independent House/Villa               other location
# 7702    other society  Independent House/Villa                      Manpada
# 7883    other society  Independent House/Villa               other location
# 7928    Description :  Independent House/Villa               other location
# 7933    other society  Independent House/Villa             Santacruz (West)
# 7934    other society  Independent House/Villa             Santacruz (West)
# 7942    other society  Independent House/Villa               other location
# 8008       On Request  Independent House/Villa                         Juhu
# 10262  Not Mentioned  Not Mentioned        120000
# 10293  Not Mentioned  Not Mentioned        150000
# 10409  Not Mentioned  Not Mentioned         17000
# 10410  Not Mentioned  Not Mentioned         25000
# 10433  Not Mentioned  Not Mentioned         32500
# 10595  Not Mentioned  Not Mentioned        100000
# 10846  Not Mentioned  Not Mentioned        110000
# 10847  Not Mentioned  Not Mentioned         11000
# 11045  Not Mentioned  Not Mentioned          9000
# 11063  Not Mentioned  Not Mentioned         55000
# 11373  Not Mentioned  Not Mentioned         30000
# 11671  Not Mentioned  Not Mentioned        399000
# 11864  Not Mentioned  Not Mentioned        125000
# 11888  Not Mentioned  Not Mentioned         21000
# 12033  Not Mentioned  Not Mentioned         13000
# 12142  Not Mentioned  Not Mentioned         16500
# 12469  Not Mentioned  Not Mentioned         20000
# 13513  Not Mentioned  Not Mentioned         80000

# %%
type_index_list = df[df['type'] == 'Independent House/Villa'].index

for i in type_index_list:
    df['floor'][i] = 0
    df['total floors'][i] = 0

# %%
df['floor'].unique()
# Out:
# array(['2nd', '8th', '14th', '40th', '4th', '3rd', '19th', '11th', '1st',
#        '6th', '5th', '12th', '20th', '10th', '7th', '16th', '13th',
#        'Ground', 'Not Mentioned', '24th', '34th', '25th', '9th', '33rd',
#        '35th', '18th', '15th', '21st', 'ried', '40+', '36th', '17th',
#        '30th', '38th', '22nd', 0, '27th', '28th', '26th', '23rd', '32nd',
#        '29th', '37th', '31st', '39th'], dtype=object)

# %%
df.replace({'floor': ['Ground','ried']}, 0, inplace =True)
df.replace({'floor': '40+'},41, inplace =True)
df.replace({'floor': 'Not Mentioned'}, np.NaN, inplace =True)
df = df.replace({'floor': '[A-Za-z]'}, ' ', regex = True)
df['floor'] = df['floor'].astype(str)
df['floor'] = df['floor'].apply(lambda x: x.strip())
df = df.dropna()

# %%
df = df.drop(df[df['floor']=='nan'].index, axis=0)
df['floor'].unique()
# Out:
# array(['2', '8', '14', '40', '4', '3', '19', '11', '1', '6', '5', '12',
#        '20', '10', '7', '16', '13', '0', '24', '34', '25', '9', '33',
#        '35', '18', '15', '21', '41', '36', '17', '30', '38', '22', '27',
#        '28', '26', '23', '32', '29', '37', '31', '39'], dtype=object)

# %%
df['total floors'].unique()
# Out:
# array(['6', '12', '17', '41', '7', '19', '30', '23', '24', '8', '18', '4',
#        '11', '14', '22', '10', '3', '39', '35', '20', '21', '40', '13',
#        '15', '32', '33', '36', '16', '5', '37', '38', '27', '9', '26',
#        '25', '28', 0, '34', '29', '59', '46', '31', '2', 'Not Mentioned',
#        '45', '48', '42', '1', '60', '55', '52', '58'], dtype=object)

# %%
(df['total floors'] == 'Not Mentioned').sum()
# Out:
# 4

# %%
df[df['total floors'] == 'Not Mentioned']
# Out:
#                   society                   type       location bedrooms  \
# 1946        other society  Residential Apartment  Bandra (West)        2
# 10130  Hilla Almeida Park  Residential Apartment  Bandra (West)        2
# 10131       other society  Residential Apartment  Bandra (West)        2
# 10187       other society  Residential Apartment  Bandra (West)        3
#
#        built-up area     furnishing               age floor   total floors  \
# 1946          1200.0      Furnished  0 to 1 years old     3  Not Mentioned
# 10130         1200.0      Furnished     10+ years old     3  Not Mentioned
# 10131         1150.0      Furnished     10+ years old     4  Not Mentioned
# 10187         2000.0  Semifurnished  0 to 1 years old     5  Not Mentioned
#
#        monthly rent
# 1946          90000
# 10130         90000
# 10131         85000
# 10187        120000

# %%
df.replace({'total floors': 'Not Mentioned'}, np.NaN, inplace = True)
df = df.dropna()

# %%
df['total floors'].unique()
# Out:
# array(['6', '12', '17', '41', '7', '19', '30', '23', '24', '8', '18', '4',
#        '11', '14', '22', '10', '3', '39', '35', '20', '21', '40', '13',
#        '15', '32', '33', '36', '16', '5', '37', '38', '27', '9', '26',
#        '25', '28', 0, '34', '29', '59', '46', '31', '2', '45', '48', '42',
#        '1', '60', '55', '52', '58'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13369 entries, 0 to 13539
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   society        13369 non-null  object
#  1   type           13369 non-null  object
#  2   location       13369 non-null  object
#  3   bedrooms       13369 non-null  object
#  4   built-up area  13369 non-null  float64
#  5   furnishing     13369 non-null  object
#  6   age            13369 non-null  object
#  7   floor          13369 non-null  object
#  8   total floors   13369 non-null  object
#  9   monthly rent   13369 non-null  int64
# dtypes: float64(1), int64(1), object(8)
# memory usage: 1.1+ MB

# %%
#At last convert all columns contains numerals into integer datatype
df['bedrooms'] = df['bedrooms'].astype(int)
df['floor'] = df['floor'].astype(int)
df['total floors'] = df['total floors'].astype(int)

# %%
df.head()
# Out:
#                  society                   type                 location  \
# 0          other society  Residential Apartment            Bandra (West)
# 1          other society  Residential Apartment                Khar West
# 2  Gajra Bhoomi Symphony  Residential Apartment  Sector-20 Koparkhairane
# 3           Crescent Bay  Residential Apartment                    Parel
# 4            Ashwini CHS  Residential Apartment              Tilak Nagar
#
#    bedrooms  built-up area     furnishing                age  floor  \
# 0         2          800.0      Furnished  5 to 10 years old      2
# 1         2         1050.0      Furnished   1 to 5 years old      8
# 2         2         1050.0    Unfurnished   1 to 5 years old     14
# 3         3         2275.0  Semifurnished   1 to 5 years old     40
# 4         1          550.0  Semifurnished  5 to 10 years old      4
#
#    total floors  monthly rent
# 0             6         85000
# 1            12        110000
# 2            17         32000
# 3            41        150000
# 4             7         27000

# %%
def plot_num(df, columns):
  data = df

  for column in columns:
      plt.figure(figsize=(16,4))

      plt.subplot(1,3,1)
      sns.histplot(data[column], kde=True)
      plt.title(f'{column}  Distribution')

      plt.subplot(1,3,2)
      sns.boxplot(y = data[column], showmeans=True)
      plt.title(f'{column}  Distribution')

      plt.subplot(1,3,3)
      counts, bins = np.histogram(data[column])
      cdf = np.cumsum (counts)
      plt.plot (bins[1:], cdf/cdf[-1])
      plt.yticks(np.arange(0,1.05,.05))
      plt.title(f'{column}  cdf')
      plt.show()

# %%
int_columns = df.columns[df.dtypes!='object']
plot_num(df,int_columns)

# %%
# Quantiles
for column in int_columns:
    print(f'For {column}:')

    print('3º Quartile:', df[column].quantile(q = 0.75))
    print('95 Quantile:', df[column].quantile(q = 0.95))
    print('Max:', df[column].quantile(q = 1.00),'\n')
# Out:
# For bedrooms:
# 3º Quartile: 3.0
# 95 Quantile: 4.0
# Max: 9.0
#
# For built-up area:
# 3º Quartile: 1450.0
# 95 Quantile: 2400.0
# Max: 41548.654
#
# For floor:
# 3º Quartile: 12.0
# 95 Quantile: 24.0
# Max: 41.0
#
# For total floors:
# 3º Quartile: 23.0
# 95 Quantile: 41.0
# Max: 60.0
#
# For monthly rent:
# 3º Quartile: 70000.0
# 95 Quantile: 180000.0
# Max: 1490000.0

# %%
df['bedrooms'] = df['bedrooms'].apply(lambda x: x if x<5 else 5)
df['total floors'] = df['total floors'].apply(lambda x: x if x<41 else 41)

# %%
df['built-up area'].quantile(q = 0.99)
# Out:
# 3500.0

# %%
df.drop(df[df['built-up area']>3500].index, axis=0, inplace=True)

# %%
int_columns = df.columns[df.dtypes!='object']
plot_num(df, int_columns)

# %%
sns.histplot(df['monthly rent'], kde=True)
plt.ticklabel_format(style='plain')
plt.xticks(rotation=45)
plt.show()

# %%
print('95th', df['monthly rent'].quantile(q = 0.95))
print('97th', df['monthly rent'].quantile(q = 0.97))
print('99th', df['monthly rent'].quantile(q = 0.99))
# Out:
# 95th 160000.0
# 97th 220000.0
# 99th 300000.0

# %%
df.drop(df[df['monthly rent']>200000].index, axis=0, inplace=True)

# %%
int_columns = df.columns[df.dtypes!='object']
plot_num(df, int_columns)

# %%
df
# Out:
#                      society                   type                 location  \
# 0              other society  Residential Apartment            Bandra (West)
# 1              other society  Residential Apartment                Khar West
# 2      Gajra Bhoomi Symphony  Residential Apartment  Sector-20 Koparkhairane
# 3               Crescent Bay  Residential Apartment                    Parel
# 4                Ashwini CHS  Residential Apartment              Tilak Nagar
# ...                      ...                    ...                      ...
# 13535          other society  Residential Apartment               Prabhadevi
# 13536          Runwal Greens  Residential Apartment            Mulund (West)
# 13537          other society  Residential Apartment           other location
# 13538          other society  Residential Apartment       Sector 19 Kharghar
# 13539          other society  Residential Apartment            Bandra (West)
#
#        bedrooms  built-up area     furnishing                age  floor  \
# 0             2          800.0      Furnished  5 to 10 years old      2
# 1             2         1050.0      Furnished   1 to 5 years old      8
# 2             2         1050.0    Unfurnished   1 to 5 years old     14
# 3             3         2275.0  Semifurnished   1 to 5 years old     40
# 4             1          550.0  Semifurnished  5 to 10 years old      4
# ...         ...            ...            ...                ...    ...
# 13535         3         2529.0      Furnished   1 to 5 years old     12
# 13536         3         1382.0  Semifurnished   0 to 1 years old     27
# 13537         3         1750.0    Unfurnished      10+ years old      9
# 13538         2          950.0  Semifurnished  5 to 10 years old      8
# 13539         3         2500.0      Furnished  5 to 10 years old      5
#
#        total floors  monthly rent
# 0                 6         85000
# 1                12        110000
# 2                17         32000
# 3                41        150000
# 4                 7         27000
# ...             ...           ...
# 13535            32        175000
# 13536            40         48000
# 13537            16        200000
# 13538            10         25500
# 13539            10        120000
#
# [12797 rows x 10 columns]

# %%
df.to_csv('Mumbai_99acers_cleaned.csv', index=False)

# %%
df1 = df.copy()
int_columns = df1.columns[df1.dtypes!='object']

for column in int_columns:
  df1[column] = df1[column].apply(lambda x: np.log(x) if x!=0 else x)

# %%
plot_num(df1,int_columns)

# %%
df['monthly rent'] = df['monthly rent'].apply(np.log)

# %%
df.to_csv('Mumbai_99acers_logtransformed.csv', index=False)
